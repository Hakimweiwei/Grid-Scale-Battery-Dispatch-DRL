# %% [markdown]
# # EDA 1: Price Volatility
# Analyzing AEMO price volatility.

# %%
import pandas as pd
import plotly.express as px
# df = pd.read_parquet('../data/processed/train.parquet')
# px.histogram(df, x='RRP')
